# %%
# %matplotlib --list
# %matplotlib notebook
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
uniform = tf.random_uniform([100], # The number of elements
                            minval = 0, # The min range
                            maxval = 1, # The max range
                            dtype = tf.float32) # The type

# %%
with tf.Session() as sess:
    print(uniform.eval())
    plt.hist(uniform.eval(), normed = True)
# Out:
# [0.39346957 0.930279   0.3273989  0.9201745  0.3652538  0.78400826
#  0.9750173  0.79607964 0.0980233  0.2884965  0.10022807 0.16668808
#  0.76499    0.79611015 0.59276676 0.6605054  0.6202638  0.98104584
#  0.05925632 0.19636405 0.62890434 0.01101542 0.04719031 0.97095275
#  0.6654997  0.7358073  0.86830664 0.18433738 0.6032158  0.40604675
#  0.85561335 0.48291254 0.96737134 0.28134978 0.02443302 0.6894524
#  0.06099284 0.05819225 0.01371574 0.64692116 0.9242028  0.39914834
#  0.6177871  0.8145046  0.035869   0.45517945 0.16184223 0.12891221
#  0.26593637 0.43972778 0.1291883  0.94812834 0.00458336 0.61986053
#  0.07214117 0.09375119 0.04045606 0.6037879  0.74524546 0.10256028
#  0.5896058  0.15864706 0.7236351  0.16420221 0.9523021  0.3880198
#  0.37628162 0.64536464 0.2024579  0.64597344 0.05020595 0.08621097
#  0.53530777 0.89418614 0.47103214 0.11623394 0.21283376 0.29939628
#  0.7651309  0.83850443 0.17400432 0.6031084  0.9583229  0.75394416
# ...
